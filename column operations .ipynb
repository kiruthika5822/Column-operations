# %% [markdown]
# # Column Operations

# %% [markdown]
# ## ABOUT THE DATASET

# %% [markdown]
# ###  This dataset is downloaded from the Kaggle dataset website and used it to do column operations using pandas.The following is a data about rape cases filed in India in various states classified based on age of victims from 2001 to 2010.

# %%
import pandas as pd

# %% [markdown]
# #### To perform the operations we need to import a library, so here pandas library is imported locally as pd.

# %%
vor=pd.read_csv("D:/SEMESTER II/Python/datasets/20_Victims_of_rape.csv")

# %% [markdown]
# #### Use read_csv function in pandas to read the dataset in to Jupyter Notebook

# %%
vor
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                        0                          0
# 1                        0                          0
# 2                        0                          0
# ...

# %%
vor['Total_Victims']=vor['Victims_Above_50_Yrs']+vor['Victims_Between_10-14_Yrs']+vor['Victims_Between_14-18_Yrs']+vor['Victims_Between_18-30_Yrs']+vor['Victims_Between_30-50_Yrs']+vor['Victims_Upto_10_Yrs']

# %% [markdown]
# #### A variable Total victims is calculated by adding all the variables based on ages.

# %%
vor
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                        0                          0
# 1                        0                          0
# 2                        0                          0
# ...

# %%
vor.rename(columns={'Area_Name':'State'})
# Out:
#                           State  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                        0                          0
# 1                        0                          0
# 2                        0                          0
# ...

# %% [markdown]
# #### Renaming variable name Area_name to State

# %%
vor_sg=vor.drop(['Subgroup'],axis=1)
vor_sg
# Out:
#                       Area_Name  Year  Victims_Above_50_Yrs  \
# 0     Andaman & Nicobar Islands  2001                     0
# 1     Andaman & Nicobar Islands  2001                     0
# 2     Andaman & Nicobar Islands  2001                     0
# 3     Andaman & Nicobar Islands  2002                     0
# 4     Andaman & Nicobar Islands  2002                     0
# ...                         ...   ...                   ...
# 1045                West Bengal  2009                     0
# 1046                West Bengal  2009                     0
# 1047                West Bengal  2010                     0
# 1048                West Bengal  2010                     0
# 1049                West Bengal  2010                     0
#
#       Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                             0                          3
# 1                             0                          1
# 2                             0                          2
# ...

# %% [markdown]
# #### Deleting an excisting column (Subgroup) from the dataset.

# %%
vor.columns=[col.upper() for col in vor]
vor
# Out:
#                       AREA_NAME  YEAR                SUBGROUP  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       VICTIMS_ABOVE_50_YRS  VICTIMS_BETWEEN_10-14_YRS  \
# 0                        0                          0
# 1                        0                          0
# 2                        0                          0
# ...

# %% [markdown]
# #### Changing variable names completely in uppercase

# %%
vor.sort_values(by='YEAR',ascending=True)
# Out:
#                       AREA_NAME  YEAR                SUBGROUP  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 812                      Punjab  2001   Victims of Other Rape
# 811                      Punjab  2001  Victims of Incest Rape
# 810                      Punjab  2001      Total Rape Victims
# 210        Dadra & Nagar Haveli  2001      Total Rape Victims
# ...                         ...   ...                     ...
# 808                  Puducherry  2010  Victims of Incest Rape
# 809                  Puducherry  2010   Victims of Other Rape
# 179                  Chandigarh  2010   Victims of Other Rape
# 177                  Chandigarh  2010      Total Rape Victims
# 1049                West Bengal  2010   Victims of Other Rape
#
#       VICTIMS_ABOVE_50_YRS  VICTIMS_BETWEEN_10-14_YRS  \
# 0                        0                          0
# 812                      1                         30
# 811                      0                          0
# ...

# %% [markdown]
# #### Arranging dataset in ascending order based on year.

# %%
vor.groupby('YEAR').sum()
# Out:
# C:\Users\mkiru\AppData\Local\Temp\ipykernel_21372\1187919877.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   vor.groupby('YEAR').sum()
#       VICTIMS_ABOVE_50_YRS  VICTIMS_BETWEEN_10-14_YRS  \
# YEAR
# 2001                   136                       2880
# 2002                   132                       1708
# 2003                   120                       1862
# 2004                   162                       2180
# 2005                   222                       2348
# 2006                   188                       2162
# 2007                   266                       2710
# 2008                   272                       2662
# 2009                   190                       3520
# 2010                   272                       2808
#
# ...

# %% [markdown]
# #### Total number of victims in each year irrespective of state.

# %%
print(vor.columns.values)
# Out:
# ['AREA_NAME' 'YEAR' 'SUBGROUP' 'VICTIMS_ABOVE_50_YRS'
#  'VICTIMS_BETWEEN_10-14_YRS' 'VICTIMS_BETWEEN_14-18_YRS'
#  'VICTIMS_BETWEEN_18-30_YRS' 'VICTIMS_BETWEEN_30-50_YRS'
#  'VICTIMS_UPTO_10_YRS' 'TOTAL_VICTIMS']

# %% [markdown]
# #### Printing variable names.

# %%
len(vor.columns.values)
# Out:
# 10

# %% [markdown]
# #### Total Number of Variables.
